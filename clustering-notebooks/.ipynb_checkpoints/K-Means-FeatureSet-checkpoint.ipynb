# %% [markdown]
# # Clustering Task 2 - K-means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylabplt
import seaborn as sns
import sklearn.cluster as cluster
import time
import sklearn.mixture as mixture
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans

import sys
sys.path.append('../resources')
import w8support as w8s

# Make sure the pic subdirectory exists
import os, errno
try:
    os.makedirs('pic')
except OSError as e:
    if e.errno != errno.EEXIST:
        raise

# %matplotlib inline

# %% [markdown]
# ## Elbow Method
# Elbow Method performance to determine optimum clusters for use with K-means

# %%
featureSub = pd.read_csv("oheTransformedData.csv")

from sklearn.decomposition import PCA
pca = PCA(0.99, whiten=True)
data = pca.fit_transform(featureSub)
data.shape

mms = MinMaxScaler()
mms.fit(data)
data_transformed = mms.transform(data)

Sum_of_squared_distances = []
K = range(1,15)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data_transformed)
    Sum_of_squared_distances.append(km.inertia_)
    

plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# ### Elbow Method Result
# As indicated from the above elbow method result, the optimal cluster number for this feature set looks to be about 6.

# %% [markdown]
# ## K-means Algorithm

# %%
sns.set_context('poster')
sns.set_color_codes()
plot_kwds = {'alpha' : 0.25, 's' : 15, 'linewidths':0}
paletteName = 'deep'
fontSize = 10
fc = '#cccccc'

from scipy.spatial.distance import cdist
outFile = 'pic/kmeans6_generated.pdf'
nClusters = 6
clusterParams = {'n_clusters':nClusters, 'random_state':0}
algName = "KMeans"

start_time = time.time()
kmeans = cluster.KMeans(**clusterParams)
labels = kmeans.fit_predict(data)
# Subsequently, this will be invoked using a function call of the form
# kmeans, labels = w8s.fitClusterLabels(data, cluster.KMeans, (), clusterParams)
end_time = time.time()
elapsed_time = end_time-start_time
print(elapsed_time)

title = '{} Clusters found by {}'.format(str(nClusters),algName)
plt = w8s.plot_2dClusters(data, labels, title, paletteName, fontSize, plot_kwds)
outFile = 'pic/{}{}_generated.pdf'.format(algName,str(nClusters))
plt.savefig(outFile)

title = '{} Clusters (with regions) found by {}'.format(str(nClusters),algName)
centres = kmeans.cluster_centers_
radii = [cdist(data[labels == i], [center]).max()
         for i, center in enumerate(centres)]
plt = w8s.overlayDisks(plt, centres, radii, fc, plot_kwds)
outFile = 'pic/{}{}withCentres_generated.pdf'.format(algName,str(nClusters))
plt.savefig(outFile)
# Out:
# 0.20150494575500488

# %%
originalFeatureSubset = pd.read_csv("originalFeatureSubset.csv")
# Add cluster labels to original dataframe for review and interpretation of cluster results.

originalFeatureSubset['CLUSTERS'] = pd.Series(labels, index=originalFeatureSubset.index)

# Check cluster column is present in dataframe.
originalFeatureSubset.head(5)
# Out:
#      who Years_on_Internet Web_Ordering  Age  Not_Purchasing_Too_complicated  \
# 0  93819            1-3_yr          Yes   41                               0
# 1  95708        Under_6_mo          Yes   28                               0
# 2  97218            1-3_yr          Yes   25                               0
# 3  91627            1-3_yr          Yes   28                               0
# 4  49906            1-3_yr          Yes   17                               0
#
#    Not_Purchasing_Prefer_people  Not_Purchasing_Privacy  \
# 0                             0                       0
# 1                             0                       0
# 2                             0                       1
# 3                             0                       0
# 4                             0                       0
#
#    Not_Purchasing_Security  Not_Purchasing_Easier_locally  CLUSTERS
# 0                        0                              0         4
# ...

# %% [markdown]
# ### Analyse k-means the cluster groups
# Now lets look at which features trend in to which clusters.
#
# We will start with the boolean inputs:

# %%
for x in [0, 1, 2, 3, 4, 5]:
    for col in ['Not_Purchasing_Too_complicated', 'Not_Purchasing_Prefer_people','Not_Purchasing_Privacy', 'Not_Purchasing_Security', 'Not_Purchasing_Easier_locally']:
        clusterName = str(x)
        rowCount = str(len(originalFeatureSubset.loc[(originalFeatureSubset[col]) & (originalFeatureSubset.CLUSTERS == x)]))

        print('CLUSTER ' + clusterName + ' COUNT IS: ' + rowCount + ' for feature: ' + col)
    print('************************************************************')
# Out:
# CLUSTER 0 COUNT IS: 157 for feature: Not_Purchasing_Too_complicated
# CLUSTER 0 COUNT IS: 326 for feature: Not_Purchasing_Prefer_people
# CLUSTER 0 COUNT IS: 583 for feature: Not_Purchasing_Privacy
# CLUSTER 0 COUNT IS: 880 for feature: Not_Purchasing_Security
# CLUSTER 0 COUNT IS: 706 for feature: Not_Purchasing_Easier_locally
# ************************************************************
# CLUSTER 1 COUNT IS: 26 for feature: Not_Purchasing_Too_complicated
# CLUSTER 1 COUNT IS: 116 for feature: Not_Purchasing_Prefer_people
# CLUSTER 1 COUNT IS: 263 for feature: Not_Purchasing_Privacy
# CLUSTER 1 COUNT IS: 392 for feature: Not_Purchasing_Security
# CLUSTER 1 COUNT IS: 95 for feature: Not_Purchasing_Easier_locally
# ************************************************************
# CLUSTER 2 COUNT IS: 114 for feature: Not_Purchasing_Too_complicated
# CLUSTER 2 COUNT IS: 300 for feature: Not_Purchasing_Prefer_people
# CLUSTER 2 COUNT IS: 552 for feature: Not_Purchasing_Privacy
# ...

# %%
# We get the average age per cluster next to aid in the age exploration on this feature subset
originalFeatureSubset.groupby(['CLUSTERS'])['Age'].mean()
# Out:
# CLUSTERS
# 0    24.317995
# 1    58.665541
# 2    21.423850
# 3    54.421935
# 4    36.353485
# 5    33.236774
# Name: Age, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.scatter(originalFeatureSubset['CLUSTERS'], originalFeatureSubset['Age'],)
plt.title("Average Age per Cluster")
plt.xlabel("CLUSTERS")
plt.ylabel("Age")
plt.show() # Depending on whether you use IPython or interactive mode, etc.

# %% [markdown]
# As you can see the scatter plot results align with the mean results in terms of average age per cluster.

# %%
# Next we check the Years_on_Internet options in the dataset for use with grouping for the clusters
originalFeatureSubset.Years_on_Internet.unique()
# Out:
# array(['1-3_yr', 'Under_6_mo', '4-6_yr', '6-12_mo', 'Over_7_yr'],
#       dtype=object)

# %%
# Next lets view results per cluster for most populate answer to Years_on_Internet
for x in [0, 1, 2, 3, 4, 5]:
    for result in ['1-3_yr', 'Under_6_mo', '4-6_yr', '6-12_mo', 'Over_7_yr']:
        clusterName = str(x)
        rowCount = str(len(originalFeatureSubset[originalFeatureSubset['Years_on_Internet'].str.contains(result) & (originalFeatureSubset.CLUSTERS == x)]))

        print('CLUSTER ' + clusterName + ' COUNT IS: ' + rowCount + ' for feature: ' + result + ' for Years_on_Internet')
    print('************************************************************')
# Out:
# CLUSTER 0 COUNT IS: 1144 for feature: 1-3_yr for Years_on_Internet
# CLUSTER 0 COUNT IS: 180 for feature: Under_6_mo for Years_on_Internet
# CLUSTER 0 COUNT IS: 798 for feature: 4-6_yr for Years_on_Internet
# CLUSTER 0 COUNT IS: 311 for feature: 6-12_mo for Years_on_Internet
# CLUSTER 0 COUNT IS: 240 for feature: Over_7_yr for Years_on_Internet
# ************************************************************
# CLUSTER 1 COUNT IS: 125 for feature: 1-3_yr for Years_on_Internet
# CLUSTER 1 COUNT IS: 228 for feature: Under_6_mo for Years_on_Internet
# CLUSTER 1 COUNT IS: 31 for feature: 4-6_yr for Years_on_Internet
# CLUSTER 1 COUNT IS: 199 for feature: 6-12_mo for Years_on_Internet
# CLUSTER 1 COUNT IS: 9 for feature: Over_7_yr for Years_on_Internet
# ************************************************************
# CLUSTER 2 COUNT IS: 629 for feature: 1-3_yr for Years_on_Internet
# CLUSTER 2 COUNT IS: 421 for feature: Under_6_mo for Years_on_Internet
# ...

# %%
# Next we double check the Web_Ordering options in the dataset are just Yes / No / Dont_know for use with grouping for the clusters
originalFeatureSubset.Web_Ordering.unique()
# Out:
# array(['Yes', 'No', 'Dont_know'], dtype=object)

# %%
# Next lets view results per cluster for most populate answer to Web Ordering
for x in [0, 1, 2, 3, 4, 5]:
    for result in ['Yes', 'No', 'Dont_know']:
        clusterName = str(x)
        rowCount = str(len(originalFeatureSubset[originalFeatureSubset['Web_Ordering'].str.contains(result) & (originalFeatureSubset.CLUSTERS == x)]))

        print('CLUSTER ' + clusterName + ' COUNT IS: ' + rowCount + ' for feature: ' + result + ' for Web_Ordering')
    print('************************************************************')
# Out:
# CLUSTER 0 COUNT IS: 2655 for feature: Yes for Web_Ordering
# CLUSTER 0 COUNT IS: 0 for feature: No for Web_Ordering
# CLUSTER 0 COUNT IS: 18 for feature: Dont_know for Web_Ordering
# ************************************************************
# CLUSTER 1 COUNT IS: 18 for feature: Yes for Web_Ordering
# CLUSTER 1 COUNT IS: 573 for feature: No for Web_Ordering
# CLUSTER 1 COUNT IS: 1 for feature: Dont_know for Web_Ordering
# ************************************************************
# CLUSTER 2 COUNT IS: 73 for feature: Yes for Web_Ordering
# CLUSTER 2 COUNT IS: 1449 for feature: No for Web_Ordering
# CLUSTER 2 COUNT IS: 21 for feature: Dont_know for Web_Ordering
# ************************************************************
# CLUSTER 3 COUNT IS: 1547 for feature: Yes for Web_Ordering
# CLUSTER 3 COUNT IS: 0 for feature: No for Web_Ordering
# CLUSTER 3 COUNT IS: 3 for feature: Dont_know for Web_Ordering
# ************************************************************
# ...

# %% [markdown]
# ### K-means Results Summary for Clusters for Age Related Web Purchasing Features.
# For each lcuster I have taken the approach of pullin the largest values for each clusters based on what has been analysed above.
#
# ### cluster 0
# * Average age of candidates for clsuetr 0 was 24.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security (880).
# * This candidates typical Years_on_Internet was 1-3years (1144) whch aligns with the young age group.
# * Most answered yes for Web_Ordering for this candidate (2655).
#
# ### cluster 1
# * Average age of candidates for cluster 1 was 58.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security (392).
# * This candidates typical Years_on_Internet was Under_6_mo (228).
# * Most answered No for Web_Ordering for this candidate (573).
#
# ### cluster 2
# * Average age of candidates for cluster 2 was 21.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security (794).
# * This candidates typical Years_on_Internet was 1-3_yr (629) which aligns with the young age group.
# * Most answered No for Web_Ordering for this candidate (1449).
#
# ### cluster 3
# * Average age of candidates for cluster 3 was 54.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security (597).
# * This candidates typical Years_on_Internet was 1-3_yr (605).
# * Most answered Yes for Web_Ordering for this candidate (1547).
#
# ### cluster 4
# * Average age of candidates for cluster 4 was 36.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security(949).
# * This candidates typical Years_on_Internet was 1-3_yr(1029).
# * Most answered Yes for Web_Ordering for this candidate(2582).
#
# ### cluster 5
# * Average age of candidates for cluster 5 was 33.
# * This candidates main concern for not purchasing something was Not_Purchasing_Security (760).
# * This candidates typical Years_on_Internet was Under_6_mo (430).
# * Most answered No for Web_Ordering for this candidate (1131).

# %% [markdown]
# ## Advantages / Disadvantages of K-Means for Internet Usage DataSet:
#
# ### Advantages
#
# * K-Means was quite easy to	implement.
# * Using the K-Means elbow technique I had a good idea of how many nClusters to set from the beginning.
# * K-Means is quite fast too run in comparison to the other clustering techniques used.
# * K-Means can produce	tighter	clusters than hierarchical	clustering. This can be seen in the cluster output on the scatterplot results.
# * The cluster group interpretations supported my main hypothesis for this feature subset relating to age and purchasing habits with a clear distinction between older age groupings not being as likely to purchase online.
#
# ### Disavantages
# * The	order	of	the	data	has	an	impact	on	the	final	results	with k-means which can impact assumptions made.
# * Sensitive	to	scale:	the algorithm was very sensitive to changes in scale.
# * Requires you to specify the clusters size from the outset unlike hierarchical clustering and so is not as helpful when you do not have previous domain knowledge to aid selection, which is often the case with real world data sets.
